# %% [markdown]
# <a href="https://colab.research.google.com/github/orifxon05/fibonacci-python/blob/csvfayl/13lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
try:
  df=pd.read_csv(r"C:\\Users\\orifx\\Downloads\\User_Data.csv")
  print(df)

except FileNotFoundError:
  print("File not found")
# Out:
# File not found
